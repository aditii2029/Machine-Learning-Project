# %% [markdown]
# <a href="https://colab.research.google.com/github/aditii2029/Machine-Learning-Project/blob/main/Pre_assignment_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
squares = [x*x for x in range(1, 11)]

# %%
squares
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
evens = [x for x in range(1, 51) if x % 2 == 0]

# %%
evens

# %%
names = ["python", "data", "sql"]
upper = [x.upper() for x in names]

# %%
names
upper
# Out:
# ['PYTHON', 'DATA', 'SQL']

# %%
nums = [-5, 3, -2, 8]
positive = [x for x in nums if x > 0]

# %%
positive
# Out:
# [3, 8]

# %%
result = [(x, x*x) for x in range(1, 6)]

# %%
result
# Out:
# [(1, 1), (2, 4), (3, 9), (4, 16), (5, 25)]

# %%
text = "education"
vowels = [ch for ch in text if ch in "aeiou"]

# %%
vowels
# Out:
# ['e', 'u', 'a', 'i', 'o']

# %%
matrix = [[1,2],[3,4],[5,6]]
flat = [x for row in matrix for x in row]

# %%
flat
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
nums = [-2, 4, -1, 6]
result = [0 if x < 0 else x for x in nums]

# %%
result
# Out:
# [0, 4, 0, 6]

# %%
words = ["python", "sql", "data"]
lengths = [len(w) for w in words]

# %%
lengths
# Out:
# [6, 3, 4]

# %%
words = ["Apple", "banana", "Avocado"]
result = [w for w in words if not w.lower().startswith('a')]

# %%
result
# Out:
# ['banana']

# %%
nums = [1,2,3,4]
result = ["even" if x%2==0 else "odd" for x in nums]

# %%
result
# Out:
# ['odd', 'even', 'odd', 'even']

# %%
nums = [x for x in range(1,101) if x%3==0 and x%5==0]

# %%
nums
# Out:
# [15, 30, 45, 60, 75, 90]

# %%
table = [[i*j for j in range(1,6)] for i in range(1,6)]

# %%
table
# Out:
# [[1, 2, 3, 4, 5],
#  [2, 4, 6, 8, 10],
#  [3, 6, 9, 12, 15],
#  [4, 8, 12, 16, 20],
#  [5, 10, 15, 20, 25]]

# %%
d = {"a":1, "b":2}
keys = [k for k in d]

# %%
keys
# Out:
# ['a', 'b']

# %%
text = "a1b2c3"
digits = [ch for ch in text if ch.isdigit()]

# %%
digits
# Out:
# ['1', '2', '3']

# %%
text = "data science"
result = [ch for ch in text if ch != " "]

# %%
result
# Out:
# ['d', 'a', 't', 'a', 's', 'c', 'i', 'e', 'n', 'c', 'e']

# %%
text = "programming"
result = [ch for ch in set(text) if text.count(ch) > 1]

# %%
result
# Out:
# ['m', 'r', 'g']

# %%
sentences = ["I love python", "Data is fun"]
words = [word for s in sentences for word in s.split()]

# %%
words
# Out:
# ['I', 'love', 'python', 'Data', 'is', 'fun']

# %%
nums = [1,2,2,3,3]
unique = [x for x in nums if nums.count(x) == 1]

# %%
unique
# Out:
# [1]

# %%
A = [1,2]
B = ['a','b']
pairs = [(x,y) for x in A for y in B]
pairs
# Out:
# [(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')]

# %%
#Lambda functions

# %%
add = lambda a,b: a+b

# %%
even = lambda x: x%2==0

# %%
nums = [1,2,3]
result = list(map(lambda x: x*x, nums))
result
# Out:
# [1, 4, 9]

# %%
result = list(filter(lambda x: x%2!=0, nums))
result
# Out:
# [1, 3]

# %%
t = [(1,3),(2,1),(4,2)]
sorted_t = sorted(t, key=lambda x: x[1])
sorted_t

# %%
pal = lambda s: s == s[::-1]
pal

# %%
max3 = lambda a,b,c: max(a,b,c)
max3

# %%
rev = lambda s: s[::-1]
rev

# %%
nums = ["1","2","3"]
result = list(map(lambda x: int(x), nums))
result

# %%
lst = ["hi", "", "hello"]
result = list(filter(lambda x: x!="", lst))
result

# %%
from functools import reduce
fact = lambda n: reduce(lambda a,b: a*b, range(1,n+1))
fact
# Out:
# <function __main__.<lambda>(n)>

# %%
large = lambda a,b: a if a>b else b
large
# Out:
# <function __main__.<lambda>(a, b)>

# %%
div5 = lambda x: x%5==0
div5
# Out:
# <function __main__.<lambda>(x)>

# %%
result = list(map(lambda x: x+10, nums))
result
# Out:
# [11, 12, 13]

# %%
people = [{"age":30},{"age":20}]
sorted_p = sorted(people, key=lambda x: x["age"])
sorted_p
# Out:
# [{'age': 20}, {'age': 30}]

# %%
vowel = lambda ch: ch.lower() in "aeiou"
vowel
# Out:
# <function __main__.<lambda>(ch)>

# %%
words = ["python","data","science"]
result = list(filter(lambda x: len(x)>5, words))
result
# Out:
# ['python', 'science']

# %%
area = lambda r: 3.14*r*r
area
# Out:
# <function __main__.<lambda>(r)>

# %%
nums = [1,2,2,3]
result = list(filter(lambda x: nums.count(x)==1, nums))
result
# Out:
# [1, 3]

# %%
product = reduce(lambda a,b: a*b, nums)
product
# Out:
# 12

# %%
abs_val = lambda x: abs(x)
abs_val
# Out:
# <function __main__.<lambda>(x)>

# %%
words = ["hi","hello","python"]
sorted_words = sorted(words, key=lambda x: len(x))
sorted_words
# Out:
# ['hi', 'hello', 'python']

# %%
text = "PyThOn"
result = list(filter(lambda x: x.isupper(), text))
result
# Out:
# ['P', 'T', 'O']

# %%
calc = lambda x: x*x if x%2==0 else x*x*x
calc
# Out:
# <function __main__.<lambda>(x)>

# %%
result = list(map(lambda c: (c*9/5)+32, nums))
result
# Out:
# [33.8, 35.6, 35.6, 37.4]

# %%
ana = lambda a,b: sorted(a)==sorted(b)
ana
# Out:
# <function __main__.<lambda>(a, b)>

# %%
lst = [1,"a",2,"3"]
result = list(filter(lambda x: type(x)==int, lst))

result
# Out:
# [1, 2]

# %%
nums = [1,-2,3]
result = any(map(lambda x: x<0, nums))
result
# Out:
# True

# %%
mul = lambda n: lambda x: x*n
mul
# Out:
# <function __main__.<lambda>(n)>

# %%
name= input("enter the name")

r=" "
for i in range(len(name), 0, -2):
    r= r+ name[max(0,i-2):i]
print(r)
# Out:
# enter the nameAditi pandey
#  eyndpai itAd
